# %% [markdown]
# <a href="https://colab.research.google.com/github/rashidkisejjere0784/A-comparison-of-machine-learning-models-for-temperature-prediction-in-Uganda/blob/main/Explainable_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA

# %%
data = pd.read_csv('/content/heart_failure_clinical_records.csv')
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  55.0        0                       748         0                 45
# 1  65.0        0                        56         0                 25
# 2  45.0        0                       582         1                 38
# 3  60.0        1                       754         1                 40
# 4  95.0        1                       582         0                 30
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  263358.03               1.3           137    1
# 1                    0  305000.00               5.0           130    1
# 2                    0  319000.00               0.9           140    0
# 3                    1  328000.00               1.2           126    1
# 4                    0  461000.00               2.0           132    1
#
#    smoking  time  DEATH_EVENT
# 0        1    88            0
# 1        0   207            0
# 2        0   244            0
# 3        0    90            0
# 4        0    50            1

# %%
data.describe()
# Out:
#                age      anaemia  creatinine_phosphokinase     diabetes  \
# count  5000.000000  5000.000000               5000.000000  5000.000000
# mean     60.288736     0.474400                586.760600     0.439400
# std      11.697243     0.499394                976.733979     0.496364
# min      40.000000     0.000000                 23.000000     0.000000
# 25%      50.000000     0.000000                121.000000     0.000000
# 50%      60.000000     0.000000                248.000000     0.000000
# 75%      68.000000     1.000000                582.000000     1.000000
# max      95.000000     1.000000               7861.000000     1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count        5000.000000          5000.000000    5000.000000
# mean           37.734600             0.364800  265075.404370
# std            11.514855             0.481422   97999.758622
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  215000.000000
# 50%            38.000000             0.000000  263358.030000
# 75%            45.000000             1.000000  310000.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium          sex      smoking         time  \
# count       5000.000000   5000.000000  5000.000000  5000.000000  5000.000000
# mean           1.369106    136.808200     0.645600     0.311800   130.678800
# std            1.009750      4.464236     0.478379     0.463275    77.325928
# min            0.500000    113.000000     0.000000     0.000000     4.000000
# 25%            0.900000    134.000000     0.000000     0.000000    74.000000
# 50%            1.100000    137.000000     1.000000     0.000000   113.000000
# 75%            1.400000    140.000000     1.000000     1.000000   201.000000
# max            9.400000    148.000000     1.000000     1.000000   285.000000
#
#        DEATH_EVENT
# count  5000.000000
# mean      0.313600
# std       0.464002
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
data.hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'anaemia'}>,
#         <Axes: title={'center': 'creatinine_phosphokinase'}>,
#         <Axes: title={'center': 'diabetes'}>],
#        [<Axes: title={'center': 'ejection_fraction'}>,
#         <Axes: title={'center': 'high_blood_pressure'}>,
#         <Axes: title={'center': 'platelets'}>,
#         <Axes: title={'center': 'serum_creatinine'}>],
#        [<Axes: title={'center': 'serum_sodium'}>,
#         <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'smoking'}>,
#         <Axes: title={'center': 'time'}>],
#        [<Axes: title={'center': 'DEATH_EVENT'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
y = data['DEATH_EVENT']
X = data.drop('DEATH_EVENT', axis = 'columns')

# %%
y.value_counts()
# Out:
# DEATH_EVENT
# 0    3432
# 1    1568
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler().fit(X) # scale the data

# %%
X_scaled = scaler.transform(X)

# %%
# Split the data into training and testing sets
# stratify=y ensures that the class distribution is preserved in both sets
train_X, test_X, train_y, test_y = train_test_split(X_scaled, y, stratify=y)

# Check the distribution of classes in both training and testing sets
np.unique(train_y, return_counts=True), np.unique(test_y, return_counts=True)
# Out:
# ((array([0, 1]), array([2574, 1176])), (array([0, 1]), array([858, 392])))

# %%
# Import the RandomOverSampler from imbalanced-learn library
from imblearn.over_sampling import RandomOverSampler

# Apply random oversampling to the training data
# random_state=42 ensures reproducibility
train_X_sampled, train_y_sampled = RandomOverSampler(random_state=42).fit_resample(train_X, train_y)

# Check the distribution of classes in the resampled target variable
# np.unique returns unique values and their counts
np.unique(train_y_sampled, return_counts=True)
# Out:
# (array([0, 1]), array([2574, 2574]))

# %% [markdown]
# # Interpretable ML

# %%
# !pip install interpret -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 34.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 34.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.8/778.8 kB 34.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.8/247.8 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.6 MB/s eta 0:00:00
#   Building wheel for dash-cytoscape (setup.py) ... done

# %%
from interpret.glassbox import LogisticRegression, ClassificationTree, ExplainableBoostingClassifier
from interpret import show
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %% [markdown]
# ## Logisitic Regression

# %% [markdown]
# <p align = 'center'>
#  <img src="https://www.saedsayad.com/images/LogReg_1.png">
# </p>
#
# ### Multiple Linear Regression Formula
#
# The general form of the multiple linear regression equation is:
#
# $
# Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + \beta_3 X_3 + \cdots + \beta_n X_n + \epsilon
# $
#
# where:
#
# - $ Y $ is the dependent variable (the outcome you are trying to predict).
# - $ \beta_0 $ is the intercept (the value of $ Y $ when all independent variables are zero).
# - $ \beta_1, \beta_2, \beta_3, \ldots, \beta_n $ are the coefficients (the change in $ Y $ for a one-unit change in the respective independent variable).
# - $ X_1, X_2, X_3, \ldots, X_n $ are the independent variables (the predictors).
# - $ \epsilon $ is the error term (the difference between the actual and predicted values of $ Y $).
#
# The goal of multiple linear regression is to estimate the coefficients $ \boldsymbol{\beta} $ that minimize the sum of the squared differences between the observed values and the values predicted by the model.

# %%
# Initialize a Logistic Regression model
# random_state=42 ensures reproducibility
# feature_names=X.columns assigns names to the features for interpretability
lr = LogisticRegression(random_state=42, feature_names=X.columns)

# Fit the model on the oversampled training data
lr.fit(train_X_sampled, train_y_sampled)

# %%
print(classification_report(lr.predict(train_X_sampled), train_y_sampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      2635
#            1       0.80      0.82      0.81      2513
#
#     accuracy                           0.81      5148
#    macro avg       0.81      0.81      0.81      5148
# weighted avg       0.81      0.81      0.81      5148

# %%
print(classification_report(lr.predict(test_X), test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       802
#            1       0.81      0.71      0.75       448
#
#     accuracy                           0.84      1250
#    macro avg       0.83      0.81      0.82      1250
# weighted avg       0.83      0.84      0.83      1250

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
local_explanation = lr.explain_local(test_X[:100], test_y[:100])
show(local_explanation)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-209762d9-fa45-4aad-b57d-0840a05cde1a"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-209762d9-fa45-4aad-b57d-0840a05cde1a", {"name": "LogisticRegression_0", "overall": {"type": "none", "figure": "null", "help": {}}, "specific": [{"type": "plotly", "figure": {"data": [{"marker": {"color": ["#ff7f0e", "#1f77b4", "#1f77b4", "#ff7f0e", "#1f77b4", "#1f77b4", "#ff7f0e", "#1f77b4", "#1f77b4", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#808080"]}, "orientation": "h", "x": [0.01622981556455713, -0.042071488364794886, -0.042488988026568135, 0.042640518240884925, -0.0852648362840009, -0.09448430414801173, 0.14368443615463336, -0.18371133302460887, -0.4950760646291, 0.5538308391782786, 0.7001164606971313, 1.371915671611826, -0.6162782274420588], "y": ["platelets (-0.50)", "diabetes (-0.89)", "anaemia (-0.95)", "smoking (-0.67)", "creatinine_phosphokinase (-0.28)", "sex (-1.35)", "high_blood_pressure (1.32)", "ejection_fraction (0.20)", "age (-0.88)", "serum_sodium (-1.30)", "serum_creatinine (0.92)", "time (-0.91)", "Intercept"], "type": "bar"}], "layout": {"title": {"text": "Actual: 0.781 | Predicted: 0.781"}, "xaxis": {"range": [-1.371915671611826, 1.371915671611826], "title": {"text": ""}}, "yaxis": {"automargin": true, "dtick": 1, "title": {"text": ""}}, "template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpet", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "contour": [{"type": "contour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "surface": [{"type": "surface", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "mesh3d": [{"type": "mesh3d", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "scatter": [{"fillpattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}, "type": ...

# %%
global_explanation = lr.explain_global()

# %%
show(global_explanation)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-3d758c9a-e923-4858-a001-84fa5619aaef"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-3d758c9a-e923-4858-a001-84fa5619aaef", {"name": "LogisticRegression_1", "overall": {"type": "plotly", "figure": {"data": [{"marker": {"color": ["#1f77b4", "#ff7f0e", "#ff7f0e", "#1f77b4", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#1f77b4", "#ff7f0e", "#ff7f0e", "#1f77b4", "#1f77b4", "#808080"]}, "orientation": "h", "x": [-0.032406435942028036, 0.04472308211899481, 0.04752087150604634, -0.06334929018327591, 0.07000430764350711, 0.10888847066092101, 0.30983981387647413, -0.42563686516636645, 0.5627946504864977, 0.7593474154135865, -0.9336972607874674, -1.5007900954719418, -0.6162782274420588], "y": ["platelets", "anaemia", "diabetes", "smoking", "sex", "high_blood_pressure", "creatinine_phosphokinase", "serum_sodium", "age", "serum_creatinine", "ejection_fraction", "time", "Intercept"], "type": "bar"}], "layout": {"title": {"text": "Overall Importance:<br>Coefficients"}, "xaxis": {"range": [-1.5007900954719418, 1.5007900954719418], "title": {"text": ""}}, "yaxis": {"automargin": true, "dtick": 1, "title": {"text": ""}}, "template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpet", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "contour": [{"type": "contour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "surface": [{"type": "surface", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "mesh3d": [{"type": "mesh3d", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "scatter": [{"fillpattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}, "type": "scatter"}], "parcoords": [{"type": "parcoords", "line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}}], "scatterpolargl": [{"type": "scatterpol ...

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# <p align = 'center'>
#  <img src="https://www.ge.com/digital/documentation/csense/version2023/Decision%20Tree%20Application/assets/images/DecisionTreeexample.gif">
# </p>

# %%
data['sex'].value_counts()
# Out:
# sex
# 1    3228
# 0    1772
# Name: count, dtype: int64

# %%
tree = ClassificationTree(feature_names= X.columns).fit(train_X_sampled, train_y_sampled)

# %%
print(classification_report(tree.predict(train_X_sampled), train_y_sampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      2760
#            1       0.84      0.90      0.87      2388
#
#     accuracy                           0.87      5148
#    macro avg       0.87      0.87      0.87      5148
# weighted avg       0.88      0.87      0.87      5148

# %%
print(classification_report(tree.predict(test_X), test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       869
#            1       0.82      0.85      0.84       381
#
#     accuracy                           0.90      1250
#    macro avg       0.88      0.88      0.88      1250
# weighted avg       0.90      0.90      0.90      1250

# %%
local_explanations = tree.explain_local(test_X[:100], test_y[:100])
show(local_explanations)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-12e2c898-1e08-4ff7-8614-379d3a1b06da"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-12e2c898-1e08-4ff7-8614-379d3a1b06da", {"name": "ClassificationTree_0", "overall": {"type": "none", "figure": "null", "help": {}}, "specific": [{"type": "cytoscape", "figure": "{\"elements\": [{\"data\": {\"id\": \"1\", \"label\": \"time <= -0.74\\n# Obs: 2574, 2574\", \"feature\": \"time\", \"weight\": 2}}, {\"data\": {\"id\": \"2\", \"label\": \"age <= -1.61\\n# Obs: 161, 1699\", \"feature\": \"age\", \"weight\": 2}}, {\"data\": {\"id\": \"3\", \"label\": \"serum_creatinine <= -0.37\\n# Obs: 16, 1\", \"feature\": \"serum_creatinine\", \"weight\": 1}}, {\"data\": {\"id\": \"4\", \"label\": \"Impurity: 0.00\\n# Obs: 16, 0\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"id\": \"5\", \"label\": \"Impurity: 0.00\\n# Obs: 0, 1\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"id\": \"6\", \"label\": \"serum_sodium <= -0.07\\n# Obs: 145, 1698\", \"feature\": \"serum_sodium\", \"weight\": 2}}, {\"data\": {\"id\": \"7\", \"label\": \"Impurity: 0.04\\n# Obs: 18, 974\", \"feature\": null, \"weight\": 2}}, {\"data\": {\"id\": \"8\", \"label\": \"Impurity: 0.25\\n# Obs: 127, 724\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"id\": \"9\", \"label\": \"serum_creatinine <= -0.02\\n# Obs: 2413, 875\", \"feature\": \"serum_creatinine\", \"weight\": 1}}, {\"data\": {\"id\": \"10\", \"label\": \"ejection_fraction <= -0.89\\n# Obs: 2084, 297\", \"feature\": \"ejection_fraction\", \"weight\": 1}}, {\"data\": {\"id\": \"11\", \"label\": \"Impurity: 0.46\\n# Obs: 209, 121\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"id\": \"12\", \"label\": \"Impurity: 0.16\\n# Obs: 1875, 176\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"id\": \"13\", \"label\": \"ejection_fraction <= -0.45\\n# Obs: 329, 578\", \"feature\": \"ejection_fraction\", \"weight\": 1}}, {\"data\": {\"id\": \"14\", \"label\": \"Impurity: 0.27\\n# Obs: 89, 455\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"id\": \"15\", \"label\": \"Impurity: 0.45\\n# Obs: 240, 123\", \"feature\": null, \"weight\": 1}}, {\"data\": {\"source\": \"3\", \"target\": \"4\", \"edge_weight\": 0.046620046620046623, \"weight\": 1}}, {\"data\": {\"source\": \"3\", \"target\": \"5\", \"edge_weight\": 0.002913752913752914, \"weight\": 1}}, {\"data\": {\"source\": \"6\", \"target\": \"7\", \"edge_weight\": 2.8904428904428907, \"weight\": 2}}, {\"data\": {\"source\": \"6\", \"target\": \"8\", \"edge_weight\": 2.4796037296037294, \"weight\": 1}}, {\"data\": {\"source\": \"2\", \"target\": \"3\", \"edge_weight\": 0.049533799533799536, \"weight\": 1}}, {\"data\": {\"source\": \"2\", \"target\": \"6\", \"edge_weight\": 5.370046620046621, \"weight\": 2}}, {\"data\": {\"source\": \"10\", \"target\": \"11\", \"edge_weight\": 0.9615384615384615, \"weight\": 1}}, {\"data\": {\"source\": \"10\", \"target\": \"12\", \"edge_weight\": 5.976107226107226, \"weight\": 1}}, {\"data\": {\"source\": \"13\", \"target\": \"14\", \"edge_weight\": 1.5850815850815851, \"weight\": 1}}, {\"data\": {\"source\": \"13\", \"target\": \"15\", \"edge_weight\": 1.0576923076923077, \"weight\": 1}}, {\"data\": {\"source\": \"9\", \"target\": \"10\", \"edge_weight\": 6.937645687645688, \"weight\": 1}}, {\"data\": {\"source\": \"9\", \"target\": \"13\", \"edge_weight\": 2.6427738927738926, \"weight\": 1}}, {\"data\": {\"source\": \"1\", \"target\": \"2\", \"edge_weight\": 5.419580419580419, \"weight\": 2}}, {\"data\": {\"source\": \"1\", \"target\": \"9\", \"edge_weight\": 9.58041958041958, \"weight\": 1}}], \"layout\": {\"name\": \"breadthfirst\", \"roots\": \"[id = \\\"1\\\"]\"}, \"style\": {\"width\": \"100%\", \"height\": \"390px\"}, \"stylesheet\": [{\"selector\": \"edge\", \"style\": {\"label\": \"data(label)\", \"line-color\": \"#1f77b4\", \"width\": \"data(edge_weight)\", \"line-style\": \"dotted\"}}, {\"selector\": \"node\", \"style\": {\"label\": \"data(label)\", \"text-wrap\": \"wrap\", \"background-color\": \"#3a729b\", \"font-size\": 20, \"font-weight\": 500}}, ...

# %%
global_explanations = tree.explain_global()
show(global_explanations)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-c5f5690a-eb47-42f1-b0f4-50693378bbd4"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-c5f5690a-eb47-42f1-b0f4-50693378bbd4", {"name": "ClassificationTree_1", "overall": {"type": "cytoscape", "figure": "{\"elements\": [{\"data\": {\"id\": \"1\", \"label\": \"time <= -0.74\\n# Obs: 2574, 2574\", \"feature\": \"time\"}}, {\"data\": {\"id\": \"2\", \"label\": \"age <= -1.61\\n# Obs: 161, 1699\", \"feature\": \"age\"}}, {\"data\": {\"id\": \"3\", \"label\": \"serum_creatinine <= -0.37\\n# Obs: 16, 1\", \"feature\": \"serum_creatinine\"}}, {\"data\": {\"id\": \"4\", \"label\": \"Impurity: 0.00\\n# Obs: 16, 0\", \"feature\": null}}, {\"data\": {\"id\": \"5\", \"label\": \"Impurity: 0.00\\n# Obs: 0, 1\", \"feature\": null}}, {\"data\": {\"id\": \"6\", \"label\": \"serum_sodium <= -0.07\\n# Obs: 145, 1698\", \"feature\": \"serum_sodium\"}}, {\"data\": {\"id\": \"7\", \"label\": \"Impurity: 0.04\\n# Obs: 18, 974\", \"feature\": null}}, {\"data\": {\"id\": \"8\", \"label\": \"Impurity: 0.25\\n# Obs: 127, 724\", \"feature\": null}}, {\"data\": {\"id\": \"9\", \"label\": \"serum_creatinine <= -0.02\\n# Obs: 2413, 875\", \"feature\": \"serum_creatinine\"}}, {\"data\": {\"id\": \"10\", \"label\": \"ejection_fraction <= -0.89\\n# Obs: 2084, 297\", \"feature\": \"ejection_fraction\"}}, {\"data\": {\"id\": \"11\", \"label\": \"Impurity: 0.46\\n# Obs: 209, 121\", \"feature\": null}}, {\"data\": {\"id\": \"12\", \"label\": \"Impurity: 0.16\\n# Obs: 1875, 176\", \"feature\": null}}, {\"data\": {\"id\": \"13\", \"label\": \"ejection_fraction <= -0.45\\n# Obs: 329, 578\", \"feature\": \"ejection_fraction\"}}, {\"data\": {\"id\": \"14\", \"label\": \"Impurity: 0.27\\n# Obs: 89, 455\", \"feature\": null}}, {\"data\": {\"id\": \"15\", \"label\": \"Impurity: 0.45\\n# Obs: 240, 123\", \"feature\": null}}, {\"data\": {\"source\": \"3\", \"target\": \"4\", \"edge_weight\": 0.046620046620046623}}, {\"data\": {\"source\": \"3\", \"target\": \"5\", \"edge_weight\": 0.002913752913752914}}, {\"data\": {\"source\": \"6\", \"target\": \"7\", \"edge_weight\": 2.8904428904428907}}, {\"data\": {\"source\": \"6\", \"target\": \"8\", \"edge_weight\": 2.4796037296037294}}, {\"data\": {\"source\": \"2\", \"target\": \"3\", \"edge_weight\": 0.049533799533799536}}, {\"data\": {\"source\": \"2\", \"target\": \"6\", \"edge_weight\": 5.370046620046621}}, {\"data\": {\"source\": \"10\", \"target\": \"11\", \"edge_weight\": 0.9615384615384615}}, {\"data\": {\"source\": \"10\", \"target\": \"12\", \"edge_weight\": 5.976107226107226}}, {\"data\": {\"source\": \"13\", \"target\": \"14\", \"edge_weight\": 1.5850815850815851}}, {\"data\": {\"source\": \"13\", \"target\": \"15\", \"edge_weight\": 1.0576923076923077}}, {\"data\": {\"source\": \"9\", \"target\": \"10\", \"edge_weight\": 6.937645687645688}}, {\"data\": {\"source\": \"9\", \"target\": \"13\", \"edge_weight\": 2.6427738927738926}}, {\"data\": {\"source\": \"1\", \"target\": \"2\", \"edge_weight\": 5.419580419580419}}, {\"data\": {\"source\": \"1\", \"target\": \"9\", \"edge_weight\": 9.58041958041958}}], \"layout\": {\"name\": \"breadthfirst\", \"roots\": \"[id = \\\"1\\\"]\"}, \"style\": {\"width\": \"100%\", \"height\": \"390px\"}, \"stylesheet\": [{\"selector\": \"edge\", \"style\": {\"label\": \"data(label)\", \"line-color\": \"#1f77b4\", \"width\": \"data(edge_weight)\", \"line-style\": \"dotted\"}}, {\"selector\": \"node\", \"style\": {\"label\": \"data(label)\", \"text-wrap\": \"wrap\", \"background-color\": \"#3a729b\", \"font-size\": 20, \"font-weight\": 500}}, {\"selector\": \"[weight > 1]\", \"style\": {\"line-color\": \"#ff7f0e\", \"background-color\": \"#ff420e\"}}]}", "help": {}}, "specific": [{"type": "cytoscape", "figure": "{\"elements\": [{\"data\": {\"id\": \"1\", \"label\": \"time <= -0.74\\n# Obs: 2574, 2574\", \"feature\": \"time\", \"weight\": 1}}, {\"data\": {\"id\": \"2\", \"label\": \"age <= -1.61\\n# Obs: 161, 1699\", \"feature\": \"age\", \"weight\": 2}}, {\"data\": {\"id\": \"3\", \"label\": \"serum_creatinine <= -0.37\\n# Obs:  ...

# %% [markdown]
# ## Explainable Boosted Machines

# %% [markdown]
# <p align = 'center'>
#  <img src="https://miro.medium.com/v2/resize:fit:1400/0*1K6IfG3HCnZ3irAw">
# </p>
#
# "https://www.youtube.com/watch?v=MREiHgHgl0k&t=0s"

# %%
ebm = ExplainableBoostingClassifier(random_state = 42).fit(train_X_sampled, train_y_sampled)

# %%
print(classification_report(ebm.predict(train_X_sampled), train_y_sampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2581
#            1       1.00      1.00      1.00      2567
#
#     accuracy                           1.00      5148
#    macro avg       1.00      1.00      1.00      5148
# weighted avg       1.00      1.00      1.00      5148

# %%
print(classification_report(ebm.predict(test_X), test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       861
#            1       0.98      0.99      0.99       389
#
#     accuracy                           0.99      1250
#    macro avg       0.99      0.99      0.99      1250
# weighted avg       0.99      0.99      0.99      1250

# %%
local_explanations = ebm.explain_local(test_X[:100], test_y[:100])
show(local_explanations)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-f054e0c9-9b49-49fb-b9ae-9546954c90db"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-f054e0c9-9b49-49fb-b9ae-9546954c90db", {"name": "ExplainableBoostingClassifier_0", "overall": {"type": "none", "figure": "null", "help": {}}, "specific": [{"type": "plotly", "figure": {"data": [{"marker": {"color": ["#1f77b4", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#1f77b4", "#ff7f0e", "#1f77b4", "#1f77b4", "#1f77b4", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#808080"]}, "orientation": "h", "x": [-0.3659414781956467, 0.3798401688039613, 0.39964250652544253, 0.5154008260282661, 0.5883991578886903, -0.6669523238411326, 0.8021121720693875, -0.8152385813804146, -0.8802499253058792, -0.9626650500807826, 0.987343857175312, 1.0147839590427088, 1.283729857460928, 1.899439741675787, 3.6381958065424285, 0.3741254029172907], "y": ["feature_0007 & feature_0011", "feature_0005 (1.32)", "feature_0004 & feature_0008", "feature_0008 (-1.30)", "feature_0002 & feature_0007", "feature_0000 & feature_0011", "feature_0000 & feature_0004", "feature_0000 (-0.88)", "feature_0004 (0.20)", "feature_0006 (-0.50)", "feature_0002 (-0.28)", "feature_0007 (0.92)", "feature_0008 & feature_0011", "feature_0000 & feature_0007", "feature_0011 (-0.91)", "Intercept"], "type": "bar"}], "layout": {"title": {"text": "Local Explanation (Actual Class: 1 | Predicted Class: 1<br />Pr(y = 1): 1.000)"}, "xaxis": {"range": [-3.6381958065424285, 3.6381958065424285], "title": {"text": "Contribution to Prediction"}}, "yaxis": {"automargin": true, "dtick": 1, "title": {"text": ""}}, "template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpet", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "contour": [{"type": "contour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "surface": [{"type": "surface", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555 ...

# %%
global_explanations = ebm.explain_global()
show(global_explanations)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-ccc803be-0611-4563-8c99-11c45f3635ab"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-ccc803be-0611-4563-8c99-11c45f3635ab", {"name": "ExplainableBoostingClassifier_1", "overall": {"type": "plotly", "figure": {"data": [{"marker": {"color": ["#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e", "#ff7f0e"]}, "orientation": "h", "x": [0.5643008861391642, 0.5928897878612948, 0.6435146231398093, 0.7087293286443334, 0.7662709544131386, 0.9063570164519303, 1.0534157056158189, 1.1096220457272241, 1.1110116382077853, 1.1438621161597542, 1.4373189187952389, 1.5547263992851132, 1.5557201868622945, 1.7917635230755966, 4.665652227426167], "y": ["feature_0002 & feature_0006", "feature_0000 & feature_0004", "feature_0004 & feature_0008", "feature_0000 & feature_0007", "feature_0008", "feature_0000 & feature_0011", "feature_0007 & feature_0011", "feature_0006", "feature_0008 & feature_0011", "feature_0000", "feature_0002", "feature_0004", "feature_0004 & feature_0011", "feature_0007", "feature_0011"], "type": "bar"}], "layout": {"title": {"text": "Global Term/Feature Importances"}, "xaxis": {"range": [0, 4.665652227426167], "title": {"text": "Mean Absolute Score (Weighted)"}}, "yaxis": {"automargin": true, "dtick": 1, "title": {"text": ""}}, "template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpet", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "contour": [{"type": "contour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "surface": [{"type": "surface", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "mesh3d": [{"type": "mesh3d", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "s ...

# %% [markdown]
# # LIME

# %%
# !pip install lime -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lime (setup.py) ... done

# %% [markdown]
# ## Introduction to LIME

# %%
from interpret.blackbox import LimeTabular # For Tabular Data
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier()
forest.fit(train_X_sampled, train_y_sampled)
# Out:
# RandomForestClassifier()

# %%
print(classification_report(forest.predict(train_X_sampled), train_y_sampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2582
#            1       1.00      1.00      1.00      2566
#
#     accuracy                           1.00      5148
#    macro avg       1.00      1.00      1.00      5148
# weighted avg       1.00      1.00      1.00      5148

# %%
print(classification_report(forest.predict(test_X), test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       864
#            1       0.98      0.99      0.98       386
#
#     accuracy                           0.99      1250
#    macro avg       0.99      0.99      0.99      1250
# weighted avg       0.99      0.99      0.99      1250

# %%
lime_explainer = LimeTabular(forest, data = train_X_sampled, feature_names=data.columns[:-1])

# %%
lime_local = lime_explainer.explain_local(test_X[:100], test_y[:100], name = 'LIME')

# %%
show(lime_local)
# Out:
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.6.2/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-517e8054-51d8-48f0-b68b-c0a053243a9f"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else {
#         // Browser
#         console.log("Browser");
#         callback(root['interpret-inline']);
#       }
#     })(this, function(interpretInline) {
#         interpretInline.RenderApp("_interpret-viz-517e8054-51d8-48f0-b68b-c0a053243a9f", {"name": "LIME", "overall": {"type": "none", "figure": "null", "help": {}}, "specific": [{"type": "plotly", "figure": {"data": [{"marker": {"color": ["#1f77b4", "#1f77b4", "#ff7f0e", "#1f77b4", "#1f77b4", "#ff7f0e", "#ff7f0e", "#1f77b4", "#ff7f0e", "#ff7f0e", "#808080"]}, "orientation": "h", "x": [-0.007034644945609435, -0.007512184987057528, 0.009381229433041045, -0.010832967272487268, -0.012297963459109251, 0.01997344091082949, 0.02748507318847056, -0.06288159451854443, 0.08522291433210218, 0.1156230403364857, 0.3841947203397904], "y": ["anaemia (-0.95)", "platelets (-0.50)", "creatinine_phosphokinase (-0.28)", "sex (-1.35)", "age (-0.88)", "time (-0.91)", "high_blood_pressure (1.32)", "ejection_fraction (0.20)", "serum_sodium (-1.30)", "serum_creatinine (0.92)", "Intercept"], "type": "bar"}], "layout": {"title": {"text": "Actual: 1 | Predicted: 1"}, "xaxis": {"range": [-0.3841947203397904, 0.3841947203397904], "title": {"text": ""}}, "yaxis": {"automargin": true, "dtick": 1, "title": {"text": ""}}, "template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpet", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "contour": [{"type": "contour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "surface": [{"type": "surface", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "mesh3d": [{"type": "mesh3d", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "scatter": [{"fillpattern": {"fillmode": "overlay", "size": 10, "solidity": 0.2}, "type": "scatter"}], "parcoords": [{"type": "parcoords", "line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}}], "scatterp ...

# %% [markdown]
# ## LIME ON IMAGE DATA

# %%
import os
import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions, preprocess_input
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
inet_model = inc_net.InceptionV3()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 [==============================] - 1s 0us/step

# %%
def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        # Load the image and resize it to 299x299 pixels (InceptionV3 input size)
        img = image.load_img(img_path, target_size=(299, 299))

        # Convert the image to a numpy array
        x = image.img_to_array(img)

        # Add a dimension to represent the batch size (1)
        x = np.expand_dims(x, axis=0)

        # Preprocess the image for InceptionV3
        x = inc_net.preprocess_input(x)

        # Add the processed image to our list
        out.append(x)

    # Stack all processed images vertically into a single numpy array
    return np.vstack(out)

# %%
# Process the image
images = transform_img_fn(['/content/Outdoor-Play-for-Children.jpg'])

# Set up the plot
plt.axis(False)  # Turn off axis

# Display the image
# Rescale pixel values from [-1, 1] to [0, 1] for display
plt.imshow(images[0] / 2 + 0.5)

# Make predictions using the InceptionV3 model
preds = inet_model.predict(images)

# Decode and print the top predictions
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# 1/1 [==============================] - 7s 7s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# ('n04371774', 'swing', 0.9809806)
# ('n02999410', 'chain', 0.0008630196)
# ('n02356798', 'fox_squirrel', 0.00055446784)
# ('n03532672', 'hook', 0.00018769813)
# ('n03126707', 'crane', 0.00018439082)

# %%
from lime import lime_image
from skimage.segmentation import mark_boundaries

explainer = lime_image.LimeImageExplainer() #initiate the Lime Image explainer

# %%
def get_explanation_and_plots(img):
    explanation = explainer.explain_instance(img.astype('double'), inet_model.predict,
                                            top_labels=5, hide_color=0, num_samples=1000)

    # First image
    temp1, mask1 = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=True)
    image1 = mark_boundaries(temp1 / 2 + 0.5, mask1)

    # Second image
    temp2, mask2 = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
    image2 = mark_boundaries(temp2 / 2 + 0.5, mask2)

    # Plot side by side
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))

    # Display the first image
    ax[0].imshow(image1)
    ax[0].set_title('Positive Only, Hide Rest')

    # Display the second image
    ax[1].imshow(image2)
    ax[1].set_title('Positive Only, Show Rest')

    # Hide axes
    for a in ax:
        a.axis('off')

    plt.tight_layout()
    plt.show()

# %%
# %%time
get_explanation_and_plots(images[0])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# CPU times: user 23.9 s, sys: 1 s, total: 24.9 s
# Wall time: 29.6 s

# %%
images = transform_img_fn(['/content/giraffe.jpg'])
plt.axis(False)
plt.imshow(images[0] / 2 + 0.5)
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# ('n02423022', 'gazelle', 0.07770037)
# ('n02437616', 'llama', 0.040180083)
# ('n02391049', 'zebra', 0.03617656)
# ('n02389026', 'sorrel', 0.028381107)
# ('n04604644', 'worm_fence', 0.019318242)

# %%
# %%time
get_explanation_and_plots(images[0])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# CPU times: user 22.6 s, sys: 1.06 s, total: 23.6 s
# Wall time: 33.3 s

# %% [markdown]
# # SHAP

# %%
# !pip install shap -qq

# %% [markdown]
# ## SHAP on Image Data

# %%
import shap
import json
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# %%
model = ResNet50(weights="imagenet")
X, y = shap.datasets.imagenet50()

# %%
url = "https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json"
with open(shap.datasets.cache(url)) as file:
    class_names = [v[1] for v in json.load(file).values()]

# %%
class_names

# %%
def pred_func(x):
    tmp = x.copy()
    preprocess_input(tmp)
    return model(tmp)

# %%
# define a masker that is used to mask out partitions of the input image.
masker = shap.maskers.Image("blur(128,128)", X[0].shape)

# create an explainer with model and image masker
explainer = shap.Explainer(pred_func, masker, output_names=class_names)

# here we explain two images using 500 evaluations of the underlying model to estimate the SHAP values
shap_values = explainer(
    X[1: 5], max_evals=100, batch_size=50, outputs=shap.Explanation.argsort.flip[:4]
)

# %%
# output with shap values
shap.image_plot(shap_values, X[1:5]/255)
