# %% [markdown]
# <a href="https://colab.research.google.com/github/rashidkisejjere0784/A-comparison-of-machine-learning-models-for-temperature-prediction-in-Uganda/blob/main/Data_ladies_second_cohort_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Data Science
# Data Science is the field that combines programming, statistics, and domain knowledge to extract insights from data.
#
#
# ### Why Data Science?
# - Used in healthcare, finance, marketing, agriculture, and more
# - Helps companies make data-driven decisions
# - Powers AI systems like recommendation engines and chatbots
#
#
# ### Data Science Lifecycle
# 1. Problem Definition
# 2. Data Collection
# 3. Data Cleaning
# 4. Exploratory Data Analysis (EDA)
# 5. Modeling
# 6. Evaluation
# 7. Deployment
#
#
# ### Tools We'll Use
# - **Python**
# - **Jupyter Notebook**
# - **NumPy**
# - **Pandas**

# %% [markdown]
# Python Basics Refresher

# %%
# Basic Python operations
x = 10
y = 3


print("Add:", x + y)
print("Multiply:", x * y)
print("Division:", x / y)
print("Power:", x ** y)


# Lists
my_list = [1, 2, 3, 4]
print("List:", my_list)

# %% [markdown]
# NumPy Essentials

# %%
import numpy as np

# %%
python_list = [1, 2, 3, 4]
numpy_array = np.array([1, 2, 3, 4])


print("Python List:", python_list)
print("NumPy Array:", numpy_array)

# %% [markdown]
# ## Creating Arrays

# %%
arr1 = np.array([10, 20, 30])
arr2 = np.zeros((2, 3))
arr3 = np.ones((3, 3))
arr4 = np.arange(0, 10, 2)
arr5 = np.random.rand(3, 3)


arr1, arr2, arr3, arr4, arr5

# %% [markdown]
# ## Indexing & Slicing

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr[0])
print(arr[1:4])
print(arr[-1])

# %% [markdown]
# ## Array Shape & Size

# %%
arr2d = np.array([[1, 2, 3], [4, 5, 6]])


print("Shape:", arr2d.shape)
print("Size:", arr2d.size)
print("Rows:", arr2d[0])
print("Specific Element (row 1, col 2):", arr2d[1, 2])

# %% [markdown]
# ## Math Operations

# %%
a = np.array([1, 2, 3])
b = np.array([10, 20, 30])


print(a + b)
print(a * b)
print(b - a)
print(b / a)

# %% [markdown]
# ## Statistics with NumPy

# %%
stats_arr = np.array([4, 6, 8, 10, 12])


print("Mean:", stats_arr.mean())
print("Median:", np.median(stats_arr))
print("Min:", stats_arr.min())
print("Max:", stats_arr.max())
print("Std Dev:", stats_arr.std())

# %% [markdown]
# ## 🐼 Pandas Introduction

# %% [markdown]
# # Pandas Introduction
# Pandas is a Python library for data manipulation and analysis.
#
#
# ### Key Components:
# - **Series** → One-dimensional data
# - **DataFrame** → Two-dimensional data (like Excel)

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Creating Series & DataFrame

# %%
# Creating a Series
s = pd.Series([10, 20, 30, 40])


# Creating a DataFrame
data = {
"Name": ["Amina", "Brian", "Cathy"],
"Age": [23, 25, 22],
"Score": [88, 92, 79]
}
df = pd.DataFrame(data)


s, df
# Out:
# (0    10
#  1    20
#  2    30
#  3    40
#  dtype: int64,
#      Name  Age  Score
#  0  Amina   23     88
#  1  Brian   25     92
#  2  Cathy   22     79)

# %% [markdown]
# # Loading & Exploring Data

# %%
df = pd.read_csv("sample_100.csv")


print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#      Name  Age  Score  Department  Salary
# 0  George   31     65   Marketing    1407
# 1  Daniel   21     78          IT    1140
# 2   Henry   20     52  Operations     557
# 3   Emily   35     69   Marketing    1133
# 4  George   24     85  Operations    1012
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        100 non-null    object
#  1   Age         100 non-null    int64
#  2   Score       100 non-null    int64
#  3   Department  100 non-null    object
#  4   Salary      100 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.0+ KB
# None
#               Age       Score       Salary
# count  100.000000  100.000000   100.000000
# mean    28.450000   75.050000  1029.610000
# std      6.012403   13.870523   290.886138
# min     20.000000   50.000000   515.000000
# 25%     23.750000   65.000000   764.500000
# ...

# %% [markdown]
# ## Selecting Columns & Rows

# %%
# Selecting columns
ages = df["Age"]


# Selecting multiple columns
subset = df[["Name", "Score"]]


# Selecting rows by index
first_row = df.iloc[0]
rows_1_to_3 = df.iloc[1:4]


ages, subset, first_row, rows_1_to_3

# %% [markdown]
# ## Sorting Data

# %%
# Sort by age
sorted_df = df.sort_values(by="Age", ascending=True)
sorted_df
# Out:
#       Name  Age  Score  Department  Salary
# 2    Henry   20     52  Operations     557
# 9    Emily   20     69          IT     617
# 15   Emily   20     88   Marketing    1396
# 47  Daniel   20     69     Finance     840
# 48  George   20     73          HR    1050
# ..     ...  ...    ...         ...     ...
# 44   Jacob   39     97  Operations     717
# 49   Henry   39     82          IT    1111
# 91   Amina   39     87          IT     926
# 64   Brian   39     67          IT    1261
# 67   Henry   39     51          HR    1107
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Handling Missing Values

# %%
# Check for missing values
print(df.isnull().sum())


# Fill missing values
filled_df = df.fillna({"Age": df["Age"].mean()})


# Drop rows with missing values
dropped_df = df.dropna()
# Out:
# Name          0
# Age           0
# Score         0
# Department    0
# Salary        0
# dtype: int64

# %% [markdown]
# ## Removing Duplicates

# %%
# Remove duplicate rows
df_no_duplicates = df.drop_duplicates()


# Count duplicates
print("Duplicates removed:", len(df) - len(df_no_duplicates))

# %% [markdown]
# ## Renaming Columns

# %%
# Rename specific columns
df_renamed = df.rename(columns={"Name": "Full_Name", "Score": "Exam_Score"})
df_renamed.head()
# Out:
#   Full_Name  Age  Exam_Score  Department  Salary
# 0    George   31          65   Marketing    1407
# 1    Daniel   21          78          IT    1140
# 2     Henry   20          52  Operations     557
# 3     Emily   35          69   Marketing    1133
# 4    George   24          85  Operations    1012

# %% [markdown]
# ## Changing Data Types

# %%
# Show current types
print(df.dtypes)


# Convert Age to float
df["Age"] = df["Age"].astype(float)
print(df.dtypes)
# Out:
# Name          object
# Age            int64
# Score          int64
# Department    object
# Salary         int64
# dtype: object
# Name           object
# Age           float64
# Score           int64
# Department     object
# Salary          int64
# dtype: object

# %% [markdown]
# ## Replacing Incorrect Data

# %%
# Example: Replace wrong age values
df["Age"] = df["Age"].replace({0: None})
df["Age"] = df["Age"].fillna(df["Age"].mean())


df.head()
# Out:
#      Name   Age  Score  Department  Salary
# 0  George  31.0     65   Marketing    1407
# 1  Daniel  21.0     78          IT    1140
# 2   Henry  20.0     52  Operations     557
# 3   Emily  35.0     69   Marketing    1133
# 4  George  24.0     85  Operations    1012

# %% [markdown]
# ## Data Analysis

# %%
# Students older than 24
older_students = df[df["Age"] > 24]


# Score above 85
high_scores = df[df["Score"] > 85]


older_students, high_scores

# %% [markdown]
# ## Grouping & Aggregation

# %%
# Example dataset with categories


sample = pd.DataFrame({
"Department": ["IT", "HR", "IT", "Finance", "HR"],
"Salary": [800, 600, 900, 700, 650]
})


# Group by department
print(sample.groupby("Department")["Salary"].mean())
# Out:
# Department
# Finance    700.0
# HR         625.0
# IT         850.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Sorting & Ranking

# %%
# Sort by scores in descending order
sorted_scores = df.sort_values(by="Score", ascending=False)


# Rank scores
ranked_df = df.copy()
ranked_df["Rank"] = df["Score"].rank(ascending=False)


sorted_scores, ranked_df
# Out:
# (      Name   Age  Score  Department  Salary
#  22   Jacob  29.0     99   Marketing    1289
#  32   Emily  34.0     98          HR    1196
#  52  Daniel  22.0     98          HR    1233
#  31   Cathy  32.0     97          HR     585
#  77   Irene  21.0     97   Marketing    1487
#  ..     ...   ...    ...         ...     ...
#  7   George  27.0     52     Finance     595
#  33   Cathy  30.0     51     Finance     784
#  67   Henry  39.0     51          HR    1107
#  34  George  23.0     50          HR    1473
#  18  Fatima  26.0     50  Operations    1498
#
#  [100 rows x 5 columns],
#        Name   Age  Score  Department  Salary  Rank
#  0   George  31.0     65   Marketing    1407  76.5
#  1   Daniel  21.0     78          IT    1140  46.5
#  2    Henry  20.0     52  Operations     557  94.5
#  3    Emily  35.0     69   Marketing    1133  65.0
#  4   George  24.0     85  Operations    1012  26.0
#  ..     ...   ...    ...         ...     ...   ...
# ...

# %% [markdown]
# ## Descriptive Statistics Recap

# %%
print("Mean Age:", df["Age"].mean())
print("Median Score:", df["Score"].median())
print("Std Dev of Scores:", df["Score"].std())

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

corr = num_df.corr()

plt.imshow(corr)
plt.colorbar()

cols = corr.columns
ticks = np.arange(len(cols))

plt.xticks(ticks, cols, rotation=45)
plt.yticks(ticks, cols)

plt.tight_layout()
plt.show()

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.pie(y="Age", figsize=(6, 6))
# Out:
# <Axes: ylabel='Age'>

# %%
df.plot(figsize=(8, 4))
# Out:
# <Axes: >
